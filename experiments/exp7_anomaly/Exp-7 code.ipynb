# %% [markdown]
# ##Exp 7: Anomaly Detection:
# Implement an anomaly detection system
# for detecting outliers in data (e.g., fraud detection) and perform
# comparative analysis. (Isolation Forest, Local Outlier Factor,
# One-Class SVM)

# %% [markdown]
# ##Imports and Setup

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print("Anomaly detection ready!")
# Out:
# Anomaly detection ready!

# %% [markdown]
# ##Load Dataset

# %%
csv_path = '/content/drive/MyDrive/AML_Lab_B19/Exp-7 Anomaly Detection/anomaly_detection_dataset_500_samples.csv'
df = pd.read_csv(csv_path)
print(f"Loaded: {df.shape}")
print("Columns:", df.columns.tolist())
print(df.head())
if df.shape[1] > 1:
    print("\nAnomaly rate (last col):", df.iloc[:,-1].value_counts(normalize=True))
